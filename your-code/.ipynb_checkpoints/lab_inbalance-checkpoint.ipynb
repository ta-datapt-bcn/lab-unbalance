# %% [markdown]
# # Inbalanced Classes
# ## In this lab, we are going to explore a case of imbalanced classes.
#
#
# Like we disussed in class, when we have noisy data, if we are not careful, we can end up fitting our model to the noise in the data and not the 'signal'-- the factors that actually determine the outcome. This is called overfitting, and results in good results in training, and in bad results when the model is applied to real data. Similarly, we could have a model that is too simplistic to accurately model the signal. This produces a model that doesnt work well (ever).

# %% [markdown]
# ### First, download the data from: https://www.kaggle.com/ntnu-testimon/paysim1. Import the dataset and provide some discriptive statistics and plots. What do you think will be the important features in determining the outcome?

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.isFraud.value_counts()
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
sns.pairplot(data=df)

# %% [markdown]
# ### What is the distribution of the outcome?

# %%
print('The proportion of fraudulent vs normal cases is a mere', df.isFraud.value_counts()[1]/df.isFlaggedFraud.value_counts()[0])
# Out:
# The proportion of fraudulent vs normal cases is a mere 0.0012908236941981616

# %% [markdown]
# ### Clean the dataset. How are you going to integrate the time variable? Do you think the step (integer) coding in which it is given is appropriate?

# %%
#I can't see any time variable, probably because the original dataset was unavailable.

# %%
df.drop('isFlaggedFraud', axis=1, inplace=True)

# %%
df.drop(['type', 'nameOrig', 'nameDest'], axis=1, inplace=True)

# %% [markdown]
# ### Run a logisitc regression classifier and evaluate its accuracy.

# %%
#Importing train/test split and logistic regression from sklearn.

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
#Defining X and y.

X = df.drop('isFraud', axis=1)
y = df['isFraud']

# %%
#Creating train/test split.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
#Creating the model.

model = LogisticRegression(max_iter=1000)

# %%
#Fitting the model

model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
print('Score with training data:', model.score(X_train, y_train))
print('Score with test data:', model.score(X_test, y_test))
# Out:
# Score with training data: 0.9982784214678859
# Score with test data: 0.9983128019589415

# %% [markdown]
# *Those results might seem great, but the data unbalance is probably making the model assign each instance to the most populated category, thus rendering the model useless. Let's take a look at a confusion matrix:*

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
print('Logistic Regression Model Accuracy : ', model.score(X_test, y_test)*100, '%')

prediction = model.predict(X_test)
print('\nConfusion matrix :')
print(confusion_matrix(y_test, prediction))
      
print('\nClassification report:')      
print(classification_report(y_test, prediction))
# Out:
# Logistic Regression Model Accuracy :  99.83128019589415 %
#
# Confusion matrix :
# [[1269705    1199]
#  [    948     672]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1270904
#            1       0.36      0.41      0.38      1620
#
#     accuracy                           1.00   1272524
#    macro avg       0.68      0.71      0.69   1272524
# weighted avg       1.00      1.00      1.00   1272524

# %% [markdown]
# *As we suspected, the model is simply assigning all cases to the same variable. This is probably due to the great imbalance.*

# %% [markdown]
# ### Now pick a model of your choice and evaluate its accuracy.

# %%
#Using XGBoost and balancing the data.

#Oversampling target data.
from imblearn.over_sampling import SMOTE
oversample = SMOTE()

X_train_oversam, y_train_oversam = oversample.fit_resample(X_train, y_train)
X_test_oversam, y_test_oversam = oversample.fit_resample(X_test, y_test)

# %%
#Verifying the oversampling result.

y_train_oversam.value_counts(normalize=True)*100
# Out:
# 0    50.0
# 1    50.0
# Name: isFraud, dtype: float64

# %%
#Using XGBoost:

#Importing:
from xgboost import XGBClassifier

#Creating the model:
XGB_model = XGBClassifier()

#Fitting the model:
XGB_model.fit(X_train_oversam, y_train_oversam)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12:37:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
# ...

# %%
#And finally, our score:

print('XGBoost Model Accuracy : ', XGB_model.score(X_test, y_test)*100, '%')

prediction = XGB_model.predict(X_test)
print('\nConfusion matrix :')
print(confusion_matrix(y_test, prediction))
      
print('\nClassification report:')      
print(classification_report(y_test, prediction))
# Out:
# XGBoost Model Accuracy :  99.4815029028922 %
#
# Confusion matrix :
# [[1264321    6583]
#  [     15    1605]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00   1270904
#            1       0.20      0.99      0.33      1620
#
#     accuracy                           0.99   1272524
#    macro avg       0.60      0.99      0.66   1272524
# weighted avg       1.00      0.99      1.00   1272524

# %% [markdown]
# ### Which model worked better and how do you know?

# %% [markdown]
# *Even with oversampling it's impossible to make a good prediction when the target attribute is so grossly unbalanced with respect to the data.*

# %% [markdown]
# <div align="right">Ironhack DA PT 2021</div>
#
# <div align="right">Xavier Esteban</div>
